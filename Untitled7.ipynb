# %%
import numpy as np
import pandas as pd

df = pd.read_csv('pan.csv')
df.head(10) #melihat bagian awal saja, rawawal
#df.tail(10) #melihat bagian akhir saja, raw terakhir
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  ...  win_equiv  opp_id      opp_fran  \
# 0            0     TRH       Huskies  ...  40.294830     NYK        Knicks
# ...

# %%
len(df)
# Out:
# 126314

# %%
df.shape
# Out:
# (126314, 23)

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.precision',2)

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
df.tail(3)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 126311             A           L      0.23   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
pd.set_option("display.max_rows",None)
df_team_id = df["team_id"].value_counts()
df_team_id
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
# CHI    4307
# PHO    4080
# ATL    4035
# MIL    4034
# POR    3870
# HOU    3820
# CLE    3810
# GSW    3701
# SEA    3547
# SAS    3515
# IND    3364
# DEN    3312
# UTA    3145
# DAL    3013
# NJN    2939
# LAC    2563
# SAC    2488
# MIA    2371
# ORL    2207
# MIN    2131
# WSB    1992
# TOR    1634
# WAS    1475
# CIN    1230
# MEM    1197
# PHW    1179
# CHH    1164
# STL    1121
# SYR    1111
# MNL     946
# BAL     866
# INA     863
# KCK     846
# KEN     846
# CHA     812
# SFW     777
# NOH     758
# NYA     736
# BUF     678
# FTW     665
# ROC     659
# OKC     631
# DNR     614
# VIR     536
# UTS     499
# SDC     492
# BLB     467
# VAN     460
# CAR     440
# DLC     433
# NOJ     410
# SDR     334
# WSC     291
# INO     282
# MLH     281
# SAA     272
# BRK     271
# NOB     268
# SDA     263
# CHS     260
# KCO     252
# STB     249
# DNA     194
# LAS     179
# SSL     178
# FLO     178
# ...

# %%
df["fran_id"].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
df.loc[df["fran_id"] == "Lakers", ["fran_id","team_id"]].value_counts()
# Out:
# fran_id  team_id
# Lakers   LAL        5078
#          MNL         946
# dtype: int64

# %%
a= df.loc[df["team_id"] == "MNL", "date_game"].min()
b= df.loc[df["team_id"] == "MNL", "date_game"].max()
#c= df.loc[df["team_id"] == "MNL", "date_game"].mean()

print(a)
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d6cfaa8eabae> in <module>
# ----> 1 a= df.loc[df["team_id"] == "MNL", "date_game"].min()
#       2 b= df.loc[df["team_id"] == "MNL", "date_game"].max()
#       3 #c= df.loc[df["team_id"] == "MNL", "date_game"].mean()
#       4
#       5 print(a)
#
# NameError: name 'df' is not defined

# %%
df.loc[df["team_id"] == "MNL", "date_game"].agg(("min", "max"))
# Out:
# min    1/1/1949
# max    4/9/1959
# Name: date_game, dtype: object

# %%
a= df.loc[df["team_id"] == "MNL", "pts"].sum()
b= df.loc[df["team_id"] == "BOS", "pts"].sum()

print(a)
print(b)
# Out:
# 88229
# 626484

# %%
df.loc[(df["team_id"] == "LAL") & (df["game_result"] == "W"), "pts"].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-19b6d840521e> in <module>
# ----> 1 df.loc[(df["team_id"] == "LAL") & (df["game_result"] == "W"), "pts"].mean()
#
# NameError: name 'df' is not defined

# %%
revenues = pd.Series([5555, 7000, 1980])
print(revenues)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-81a7f12f1b8e> in <module>
# ----> 1 revenues = pd.Series([5555, 7000, 1980])
#       2 print(revenues)
#
# NameError: name 'pd' is not defined

# %%
series_kota = pd.Series([5000,6500,11000],index=["bandung","jakarta","surabaya"])
print(series_kota)
print(type(series_kota))
# Out:
# bandung      5000
# jakarta      6500
# surabaya    11000
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
print(series_kota.values)
print(series_kota.index)
# Out:
# [ 5000  6500 11000]
# Index(['bandung', 'jakarta', 'surabaya'], dtype='object')

# %%
series_employee_count = pd.Series({"bandung" : 10 , "jakarta" : 32, "surabaya": 24})
series_employee_count
# Out:
# bandung     10
# jakarta     32
# surabaya    24
# dtype: int64

# %%
"bandung" in series_employee_count
# Out:
# True

# %%
"Cirebon" in series_employee_count
# Out:
# False

# %%
df_kota= pd.DataFrame({"revenue": series_kota, "employee" : series_employee_count})

# %%
df_kota.axes
#axis 0 = row
#axis 1 = kolom
# Out:
# [Index(['bandung', 'jakarta', 'surabaya'], dtype='object'),
#  Index(['revenue', 'employee'], dtype='object')]

# %%
df_kota.axes
# Out:
# [Index(['bandung', 'jakarta', 'surabaya'], dtype='object'),
#  Index(['revenue', 'employee'], dtype='object')]

# %%
df_kota.shape
# Out:
# (3, 2)

# %%
print("axes",df_kota.axes)

print("row:", df_kota.axes[0])
print("col:",df_kota.axes[1])
# Out:
# axes [Index(['bandung', 'jakarta', 'surabaya'], dtype='object'), Index(['revenue', 'employee'], dtype='object')]
# row: Index(['bandung', 'jakarta', 'surabaya'], dtype='object')
# col: Index(['revenue', 'employee'], dtype='object')

# %%
"points" in df.keys()
# Out:
# False

# %%
"pts" in df.keys()
# Out:
# True

# %%
series_buah = pd.Series(["apel","durian","nangka","pepaya"], index = [5,10,15,25])
series_buah
# Out:
# 5       apel
# 10    durian
# 15    nangka
# 25    pepaya
# dtype: object

# %%
series_buah.loc[5]
# Out:
# 'apel'

# %%
series_buah.iloc[0]
# Out:
# 'apel'

# %%
series_buah.loc[10]
# Out:
# 'durian'

# %%
series_buah.iloc[2]
# Out:
# 'nangka'

# %%
df_kota
# Out:
#           revenue  employee
# bandung      5000        10
# jakarta      6500        32
# surabaya    11000        24

# %%
df_kota.loc["jakarta"]
# Out:
# revenue     6500
# employee      32
# Name: jakarta, dtype: int64

# %%
df_kota.iloc[1]
# Out:
# revenue     6500
# employee      32
# Name: jakarta, dtype: int64

# %%
df_kota.iloc[1:3]
# Out:
#           revenue  employee
# jakarta      6500        32
# surabaya    11000        24

# %%
df_kota["revenue"]
# Out:
# bandung      5000
# jakarta      6500
# surabaya    11000
# Name: revenue, dtype: int64

# %%
toys = pd.DataFrame([{"name" : "ball" , "shape": "sphere"},{"name" :"rubiks cube", "shape": "cuube"} ])

# %%
toys["shape"]
# Out:
# 0    sphere
# 1     cuube
# Name: shape, dtype: object

# %%
toys.name
# Out:
# 0           ball
# 1    rubiks cube
# Name: name, dtype: object

# %%
toys["name"]
# Out:
# 0           ball
# 1    rubiks cube
# Name: name, dtype: object

# %%
### mangil row tertentu dengan kolom tertentu dari Data frame

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
df.loc[100:105, ["team_id", "fran_id","pts"]]
# Out:
#     team_id   fran_id  pts
# 100     DTF   Falcons   66
# 101     CLR    Rebels   46
# 102     PHW  Warriors   66
# 103     BOS   Celtics   54
# 104     TRH   Huskies   68
# 105     WSC  Capitols   78

# %%
df_kota.loc["jakarta": "malang", "revenue"] #row , kolom
# Out:
# jakarta    6500
# Name: revenue, dtype: int64

# %%
points = df.loc[df["pts"]>100]
points
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 256           129  194701010CHS   NBA        1     1947   1/1/1947
# 313           157  194701140TRH   NBA        1     1947  1/14/1947
# 399           200  194702020CLR   NBA        1     1947   2/2/1947
# 416           209  194702060CHS   NBA        0     1947   2/6/1947
# 444           223  194702120PIT   NBA        1     1947  2/12/1947
# ...           ...           ...   ...      ...      ...        ...
# 126301      63151  201505270GSW   NBA        0     2015  5/27/2015
# 126303      63152  201506040GSW   NBA        0     2015   6/4/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id   fran_id  ...  win_equiv  opp_id  \
# 256             26            0     STB   Bombers  ...  47.142483     CHS
# ...

# %%
df[
    (df["_iscopy"] == 0) &
    (df["pts"] > 100) &
    (df["opp_pts"] > 100) &
    (df["team_id"] == "BLB")
]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 1726        864  194902260BLB   NBA        0     1949  2/26/1949          53
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
# 5825       2913  195402220BLB   NBA        0     1954  2/22/1954          60
#
#       is_playoffs team_id    fran_id  ...  win_equiv  opp_id  opp_fran  \
# 1726            0     BLB  Baltimore  ...  38.557545     MNL    Lakers
# 4890            0     BLB  Baltimore  ...  25.797792     BOS   Celtics
# 4909            0     BLB  Baltimore  ...  24.876236     MNL    Lakers
# 5208            0     BLB  Baltimore  ...  19.579676     NYK    Knicks
# 5825            0     BLB  Baltimore  ...  20.736986     BOS   Celtics
#
# ...

# %%
df[
    (df["_iscopy"] == 0) &
    (df["team_id"].str.startswith("LA")) &
    (df["year_id"] == 1992) &
    (df["notes"].notnull())
]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id date_game  seasongame  \
# 68901      34451  199205030LAC   NBA        0     1992  5/3/1992          86
# 68903      34452  199205030LAL   NBA        0     1992  5/3/1992          86
#
#        is_playoffs team_id   fran_id  ...  win_equiv  opp_id      opp_fran  \
# 68901            1     LAC  Clippers  ...  47.888252     UTA          Jazz
# 68903            1     LAL    Lakers  ...  39.395412     POR  Trailblazers
#
#        opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  forecast  \
# 68901      107  1647.5092  1638.4095              H            W  0.499125
# 68903      102  1655.1210  1670.3677              H            L  0.406874
#
#                                             notes
# 68901  at Anaheim, CA (Anaheim Convention Center)
# 68903                            at Las Vegas, NV
#
# [2 rows x 23 columns]

# %%
df.groupby("fran_id", sort=False)["pts"].sum()
# Out:
# fran_id
# Huskies           3995
# Knicks          582497
# Stags            20398
# Falcons           3797
# Capitols         22387
# Celtics         626484
# Steamrollers     12372
# Ironmen           3674
# Bombers          17793
# Rebels            4474
# Warriors        591224
# Baltimore        37219
# Jets              4482
# Pistons         572758
# Lakers          637444
# Kings           569245
# Hawks           567261
# Denver            4818
# Olympians        22864
# Redskins          5372
# Waterloo          4921
# Packers           6193
# Sixers          585891
# Wizards         474809
# Bulls           437269
# Thunder         437735
# Squires          91127
# Stars            84940
# Rockets         432504
# Colonels         94435
# Pacers          438288
# Nuggets         445780
# Spurs           453822
# Spirits          85874
# Sounds           75582
# Floridians       49568
# Nets            417809
# Condors          49642
# Bucks           418326
# ...

# %%
df.groupby("fran_id", sort=True)["pts"].sum()
# Out:
# fran_id
# Baltimore        37219
# Bombers          17793
# Bucks           418326
# Bulls           437269
# Capitols         22387
# Cavaliers       380416
# Celtics         626484
# Clippers        380523
# Colonels         94435
# Condors          49642
# Denver            4818
# Falcons           3797
# Floridians       49568
# Grizzlies       157683
# Hawks           567261
# Heat            229103
# Hornets          84489
# Huskies           3995
# Ironmen           3674
# Jazz            363155
# Jets              4482
# Kings           569245
# Knicks          582497
# Lakers          637444
# Magic           219436
# Mavericks       309239
# Nets            417809
# Nuggets         445780
# Olympians        22864
# Pacers          438288
# Packers           6193
# Pelicans        220794
# Pistons         572758
# Raptors         158370
# Rebels            4474
# Redskins          5372
# Rockets         432504
# Sails            30080
# Sixers          585891
# ...

# %%
df[
    (df["fran_id"] == "Spurs") &
    (df["year_id"] > 2010)
].groupby(["year_id", "game_result"])["game_id"].count()
# Out:
# year_id  game_result
# 2011     L              25
#          W              63
# 2012     L              20
#          W              60
# 2013     L              30
#          W              73
# 2014     L              27
#          W              78
# 2015     L              31
#          W              58
# Name: game_id, dtype: int64

# %%
df[
    (df["fran_id"] == "Warriors") &
    (df["year_id"] == 2015)
].groupby(["is_playoffs", "game_result"])["game_id"].count()
# Out:
# is_playoffs  game_result
# 0            L              15
#              W              67
# 1            L               5
#              W              16
# Name: game_id, dtype: int64

# %%
nba = df.copy()

# %%
nba["difference"] = df.pts - df.opp_pts

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  opp_id   opp_fran  \
# 0                1            0     TRH    Huskies  ...     NYK     Knicks
# ...

# %%
nba["difference"].max()
# Out:
# 68

# %%
renamed_nba = nba.rename(
    columns={"game_result": "result", "game_location": "location"}
)

renamed_nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  opp_id  opp_fran  opp_pts  opp_elo_i  \
# 0            0     TRH  Huskies  ...     NYK    Knicks       68  1300.0000
# 1            0     NYK   Knicks  ...     TRH   Huskies       66  1300.0000
# 2            0     CHS    Stags  ...     NYK    Knicks       47  1306.7233
# 3            0     NYK   Knicks  ...     CHS     Stags       63  1300.0000
# 4            0     DTF  Falcons  ...     WSC  Capitols       50  1300.0000
#
#    opp_elo_n location  result  forecast  notes difference
# ...

# %%
elo_columns = ["elo_i", "elo_n", "opp_elo_i", "opp_elo_n"]
#nba.drop(elo_columns, inplace=True, axis=1)

nba.shape
# Out:
# (126314, 20)

# %%
nba["date_game"] = pd.to_datetime(nba["date_game"])
nba["game_location"].nunique()
# Out:
# 3

# %%
nba["game_location"] = pd.Categorical(nba["game_location"])
nba["game_location"].dtype
CategoricalDtype(categories=['A', 'H', 'N'], ordered=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-e0774676beb7> in <module>
#       1 nba["game_location"] = pd.Categorical(nba["game_location"])
#       2 nba["game_location"].dtype
# ----> 3 CategoricalDtype(categories=['A', 'H', 'N'], ordered=False)
#
# NameError: name 'CategoricalDtype' is not defined

# %%
rows_without_missing_data = nba.dropna()
rows_without_missing_data.shape
# Out:
# (5424, 20)
